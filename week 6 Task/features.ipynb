# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split

# %%
data= pd.read_csv('../week 1 task/cleaned_data.csv', index_col=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3452 entries, 1 to 4423
# Data columns (total 95 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Marital status                          3452 non-null   int64
#  1   Application order                       3452 non-null   int64
#  2   Daytime/evening attendance              3452 non-null   int64
#  3   Previous qualification                  3452 non-null   int64
#  4   Previous qualification (grade)          3452 non-null   float64
#  5   Nationality                             3452 non-null   int64
#  6   Admission grade                         3452 non-null   float64
#  7   Displaced                               3452 non-null   int64
#  8   Educational special needs               3452 non-null   int64
#  9   Debtor                                  3452 non-null   int64
#  10  Tuition fees up to date                 3452 non-null   int64
#  11  Gender                                  3452 non-null   int64
#  12  Scholarship holder                      3452 non-null   int64
#  13  Age at enrollment                       3452 non-null   int64
#  14  International                           3452 non-null   int64
#  15  Curricular units 1st sem (enrolled)     3452 non-null   float64
#  16  Curricular units 1st sem (evaluations)  3452 non-null   float64
#  17  Curricular units 1st sem (approved)     3452 non-null   float64
#  18  Curricular units 1st sem (grade)        3452 non-null   float64
#  19  Curricular units 2nd sem (enrolled)     3452 non-null   float64
#  20  Curricular units 2nd sem (evaluations)  3452 non-null   float64
#  21  Curricular units 2nd sem (approved)     3452 non-null   float64
#  22  Curricular units 2nd sem (grade)        3452 non-null   float64
#  23  Unemployment rate                       3452 non-null   float64
#  24  Inflation rate                          3452 non-null   float64
#  25  GDP                                     3452 non-null   float64
#  26  Target                                  3452 non-null   int64
#  27  Mother's occupation_0                   3452 non-null   float64
#  28  Mother's occupation_1                   3452 non-null   float64
#  29  Mother's occupation_2                   3452 non-null   float64
#  30  Mother's occupation_3                   3452 non-null   float64
#  31  Mother's occupation_4                   3452 non-null   float64
#  32  Mother's occupation_5                   3452 non-null   float64
#  33  Mother's occupation_6                   3452 non-null   float64
#  34  Mother's occupation_7                   3452 non-null   float64
#  35  Mother's occupation_9                   3452 non-null   float64
#  36  Mother's occupation_90                  3452 non-null   float64
#  37  Mother's occupation_others              3452 non-null   float64
#  38  Father's occupation_0                   3452 non-null   float64
#  39  Father's occupation_1                   3452 non-null   float64
#  40  Father's occupation_10                  3452 non-null   float64
#  41  Father's occupation_2                   3452 non-null   float64
#  42  Father's occupation_3                   3452 non-null   float64
#  43  Father's occupation_4                   3452 non-null   float64
#  44  Father's occupation_5                   3452 non-null   float64
#  45  Father's occupation_6                   3452 non-null   float64
#  46  Father's occupation_7                   3452 non-null   float64
#  47  Father's occupation_8                   3452 non-null   float64
#  48  Father's occupation_9                   3452 non-null   float64
#  49  Father's occupation_90                  3452 non-null   float64
#  50  Father's occupation_others              3452 non-null   float64
#  51  Application mode_1                      3452 non-null   float64
#  52  Application mode_17                     3452 non-null   float64
#  53  Application mode_18                     3452 non-null   float64
#  54  Application mode_39                     3452 non-null   float64
#  55  Application mode_42                     3452 non-null   float64
#  56  Application mode_43                     3452 non-null   float64
#  57  Application mode_44                     3452 non-null   float64
#  58  Application mode_51                     3452 non-null   float64
#  59  Application mode_7                      3452 non-null   float64
#  60  Application mode_others                 3452 non-null   float64
#  61  Course_33                               3452 non-null   float64
#  62  Course_8014                             3452 non-null   float64
#  63  Course_9003                             3452 non-null   float64
#  64  Course_9070                             3452 non-null   float64
#  65  Course_9085                             3452 non-null   float64
#  66  Course_9119                             3452 non-null   float64
#  67  Course_9130                             3452 non-null   float64
#  68  Course_9147                             3452 non-null   float64
#  69  Course_9238                             3452 non-null   float64
#  70  Course_9254                             3452 non-null   float64
#  71  Course_9500                             3452 non-null   float64
#  72  Course_9556                             3452 non-null   float64
#  73  Course_9670                             3452 non-null   float64
#  74  Course_9773                             3452 non-null   float64
#  75  Course_9853                             3452 non-null   float64
#  76  Course_9991                             3452 non-null   float64
#  77  Mother's qualification_1                3452 non-null   float64
#  78  Mother's qualification_12               3452 non-null   float64
#  79  Mother's qualification_19               3452 non-null   float64
#  80  Mother's qualification_2                3452 non-null   float64
#  81  Mother's qualification_3                3452 non-null   float64
#  82  Mother's qualification_34               3452 non-null   float64
#  83  Mother's qualification_37               3452 non-null   float64
#  84  Mother's qualification_38               3452 non-null   float64
#  85  Mother's qualification_others           3452 non-null   float64
#  86  Father's qualification_1                3452 non-null   float64
#  87  Father's qualification_19               3452 non-null   float64
#  88  Father's qualification_2                3452 non-null   float64
#  89  Father's qualification_3                3452 non-null   float64
#  90  Father's qualification_34               3452 non-null   float64
#  91  Father's qualification_37               3452 non-null   float64
#  92  Father's qualification_38               3452 non-null   float64
#  93  Father's qualification_others           3452 non-null   float64
#  94  AdmGrades_category                      3452 non-null   int64
# dtypes: float64(80), int64(15)
# memory usage: 2.5 MB

# %%
#Checking the variance of the numeric variables
numeric = ['Age at enrollment','Previous qualification (grade)','Admission grade', 'Unemployment rate','Inflation rate','GDP','Curricular units 1st sem (grade)','Curricular units 2nd sem (grade)','Curricular units 1st sem (enrolled)','Curricular units 1st sem (evaluations)','Curricular units 1st sem (approved)','Curricular units 2nd sem (enrolled)','Curricular units 2nd sem (evaluations)','Curricular units 2nd sem (approved)']

# %%
school_df = data.copy()

# %% [markdown]
# #  Feature Creation
#
#  Develop new features based on domain knowledge (e.g., study time per credit
# )
# • Create interaction terms between existing features
# • Implement polynomial features for numerical variables
# • Develop time-based features (e.g., time since last ex

# %%
school_df['Curricular units (Average grade)']	= (school_df['Curricular units 1st sem (grade)'] + school_df['Curricular units 2nd sem (grade)'])/2
school_df['Total Curricular units (enrolled)'] = school_df['Curricular units 1st sem (enrolled)']	+ school_df['Curricular units 2nd sem (enrolled)']
school_df['Total Curricular units (evaluations)'] = school_df['Curricular units 1st sem (evaluations)'] + school_df['Curricular units 2nd sem (evaluations)']
school_df['Total Curricular units (approved)'] = school_df['Curricular units 2nd sem (approved)']	+ school_df['Curricular units 2nd sem (approved)']
school_df['Completion_Rate_1st'] = school_df['Curricular units 1st sem (approved)'] / school_df['Curricular units 1st sem (enrolled)']
school_df['Completion_Rate_2nd'] = school_df['Curricular units 2nd sem (approved)'] / school_df['Curricular units 2nd sem (enrolled)']

# %%
# Create interaction terms
school_df['Completion_Grade_Interaction'] = school_df['Completion_Rate_1st'] * school_df['Admission grade']
school_df['Completion_Age_Interaction'] = school_df['Completion_Rate_1st'] * school_df['Age at enrollment']
school_df['Grade_Interaction'] = school_df['Admission grade'] * school_df['Previous qualification (grade)']
school_df['Previous_Age_Interaction'] = school_df['Previous qualification (grade)'] * school_df['Age at enrollment']


# Display the new interaction features
# print(school_df[['Completion_Rate_1st', 'Completion_Grade_Interaction', 
#                  'Completion_Age_Interaction', 'Grade_Interaction', 
#                  'Previous_Age_Interaction']])

# %%
sns.displot(data=school_df,x='Age at enrollment',col='Target',binwidth=10)
plt.show()

# %%
school_df['Age_cut'] = pd.qcut(school_df['Age at enrollment'],6)

# %%
school_df['Age_cut'].unique()
# Out:
# [(18.0, 19.0], (19.0, 20.0], (30.0, 70.0], (16.999, 18.0], (20.0, 22.0], (22.0, 30.0]]
# Categories (6, interval[float64, right]): [(16.999, 18.0] < (18.0, 19.0] < (19.0, 20.0] < (20.0, 22.0] < (22.0, 30.0] < (30.0, 70.0]]

# %%
school_df['Grouped Age at enrollment'] = pd.qcut(school_df['Age at enrollment'], q=6, labels=[1, 2, 3, 4, 5,6])
school_df['Grouped Age at enrollment'].value_counts()
# Out:
# Grouped Age at enrollment
# 1    820
# 2    703
# 6    571
# 5    566
# 3    433
# 4    359
# Name: count, dtype: int64

# %%
school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3452 entries, 1 to 4423
# Columns: 106 entries, Marital status to Grouped Age at enrollment
# dtypes: category(1), float64(90), int64(15)
# memory usage: 2.8 MB

# %%
numeric = [
    'Age at enrollment',
'Previous qualification (grade)',
'Admission grade',
'Curricular units 1st sem (enrolled)',
'Curricular units 1st sem (evaluations)',
'Curricular units 1st sem (approved)',
'Curricular units 1st sem (grade)',
'Curricular units 2nd sem (enrolled)',
'Curricular units 2nd sem (evaluations)',
'Curricular units 2nd sem (approved)',
'Curricular units 2nd sem (grade)',
'Unemployment rate',
'Inflation rate',
'GDP','Completion_Rate_2nd',
'Completion_Rate_1st',
'Total Curricular units (approved)',
'Total Curricular units (evaluations)',
'Total Curricular units (enrolled)',
'Curricular units (Average grade)',
'Completion_Grade_Interaction', 
'Completion_Age_Interaction',
'Grade_Interaction', 
'Previous_Age_Interaction']

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression


n = school_df[numeric]
y = school_df['Target']

# Define a range of degrees to test
degrees = [1, 2, 3]
scores = []

# Evaluate each degree using cross-validation
for degree in degrees:
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    n_poly = poly.fit_transform(n)
    
    model = LinearRegression()
    cv_score = cross_val_score(model, n_poly, y, cv=3)  # 3-fold cross-validation
    scores.append(np.mean(cv_score))

# Display results
for degree, score in zip(degrees, scores):
    print(f'Degree: {degree}, Cross-Validation Score: {score:.4f}')
# Out:
# Degree: 1, Cross-Validation Score: 0.6508
# Degree: 2, Cross-Validation Score: 0.6371
# Degree: 3, Cross-Validation Score: -163.3861

# %% [markdown]
# Since the best score is of degree one, We can't create a new feature

# %% [markdown]
# ### Feature Transformation
# • Apply log transformation to skewed numerical features
# • Bin continuous variables into categorical ones where appropriate
# • Standardize numerical features

# %%
# Checking the distribution of the numeric variables
school_df[numeric].hist(figsize=(30,20),layout=(7,6))
plt.show()

# %%
skew_data = ['Curricular units 1st sem (enrolled)',
'Curricular units 1st sem (evaluations)',
'Curricular units 1st sem (approved)','Curricular units 2nd sem (enrolled)',
'Curricular units 2nd sem (evaluations)',
'Curricular units 2nd sem (approved)','Completion_Rate_2nd',
'Completion_Rate_1st',
'Total Curricular units (approved)',
'Total Curricular units (evaluations)',
'Total Curricular units (enrolled)',
'Curricular units (Average grade)',
'Completion_Grade_Interaction', 
'Completion_Age_Interaction',
'Grade_Interaction', 
'Previous_Age_Interaction']

# %%
df = school_df.copy()

# %%
for var in skew_data:
    school_df[var] = np.log(school_df[var] + 1)

# %%
# Checking the distribution of the numeric variables
school_df[numeric].hist(figsize=(30,20),layout=(7,6))
plt.show()

# %%
school_df['Grouped Curricular units 2nd sem (grade)'] = pd.qcut(school_df['Curricular units 2nd sem (grade)'], q=5, labels=[1, 2, 3, 4, 5])
school_df['Grouped Curricular units 2nd sem (grade)'].value_counts()
# Out:
# Grouped Curricular units 2nd sem (grade)
# 2    786
# 1    701
# 5    691
# 4    678
# 3    596
# Name: count, dtype: int64

# %%
school_df['Grouped Curricular units 1st sem (grade)'] = pd.qcut(school_df['Curricular units 1st sem (grade)'], q=6, labels=[1, 2, 3, 4, 5,6])
school_df['Grouped Curricular units 1st sem (grade)'].value_counts()
# Out:
# Grouped Curricular units 1st sem (grade)
# 5    630
# 3    617
# 2    593
# 1    576
# 4    523
# 6    513
# Name: count, dtype: int64

# %%
school_df['Grouped Admission grade'] = pd.qcut(school_df['Admission grade'], q=5, labels=[1, 2, 3, 4, 5])
school_df['Grouped Admission grade'].value_counts()
# Out:
# Grouped Admission grade
# 2    698
# 1    695
# 3    689
# 5    688
# 4    682
# Name: count, dtype: int64

# %%
school_df['Grouped Previous qualification (grade)'] = pd.qcut(school_df['Previous qualification (grade)'], q=6, labels=[1, 2, 3, 4, 5,6])
school_df['Grouped Previous qualification (grade)'].value_counts()
# Out:
# Grouped Previous qualification (grade)
# 3    928
# 1    624
# 5    590
# 6    556
# 2    541
# 4    213
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
school_df[numeric] = scaler.fit_transform(school_df[numeric])

# %%
X_train = school_df.drop('Target', axis=1)
y_train= school_df['Target']


X_columns = X_train.columns

# %% [markdown]
# ## Feature selection
# 1. Correlation Analysis

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                col_name = corr_matrix.columns[i]
                col_corr.add(col_name)
    return col_corr

# %%
corr_features = correlation(X_train, 0.499)
len(set(corr_features))
# Out:
# 36

# %%
school_df.corr()['Target']
# Out:
# Marital status                              0.124439
# Application order                          -0.096279
# Daytime/evening attendance                 -0.089757
# Previous qualification                      0.161731
# Previous qualification (grade)             -0.109763
#                                               ...
# Grouped Age at enrollment                   0.332784
# Grouped Curricular units 2nd sem (grade)   -0.596415
# Grouped Curricular units 1st sem (grade)   -0.544025
# Grouped Admission grade                    -0.118634
# Grouped Previous qualification (grade)     -0.140240
# Name: Target, Length: 110, dtype: float64

# %%
corr_features
# Out:
# {'AdmGrades_category',
#  'Admission grade',
#  'Age at enrollment',
#  'Application mode_39',
#  'Completion_Age_Interaction',
#  'Completion_Grade_Interaction',
#  'Completion_Rate_1st',
#  'Completion_Rate_2nd',
#  'Course_8014',
#  'Course_9991',
#  'Curricular units (Average grade)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  "Father's occupation_0",
#  "Father's occupation_90",
#  "Father's occupation_others",
#  "Father's qualification_3",
#  "Father's qualification_34",
#  "Father's qualification_37",
#  'Grade_Interaction',
#  'Grouped Admission grade',
#  'Grouped Age at enrollment',
#  'Grouped Curricular units 1st sem (grade)',
#  'Grouped Curricular units 2nd sem (grade)',
#  'Grouped Previous qualification (grade)',
#  'International',
#  "Mother's qualification_3",
#  "Mother's qualification_34",
#  'Previous_Age_Interaction',
#  'Total Curricular units (approved)',
#  'Total Curricular units (enrolled)',
#  'Total Curricular units (evaluations)'}

# %% [markdown]
# 2. Recursive Feature Elimination

# %%
# Feature extraction
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import RFE
model = DecisionTreeClassifier()
rfe = RFE(estimator=model, n_features_to_select=35)
fit = rfe.fit(X_train, y_train)
# print("Num Features: %s" % (fit.n_features_))
# print("Selected Features: %s" % (fit.support_))
# print("Feature Ranking: %s" % (fit.ranking_))
important_features = pd.DataFrame(list(zip(X_columns,fit.support_)),columns=['Feature','Important'])
list = important_features.sort_values(by='Important', ascending=False).iloc[:36,0].to_list()

# %%
from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest Classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Get feature importances
importances = model.feature_importances_
feature_names = X_train.columns

# Create a DataFrame for visualization
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).iloc[:36]

# Plot feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance from Random Forest Classifier')
plt.show()

# %%
from sklearn.linear_model import Lasso

# Train the Random Forest Classifier
model = Lasso(alpha=0.01,random_state=42)
model.fit(X_train, y_train)

# Get feature importances
importances = model.coef_
feature_names = X_train.columns

# Create a DataFrame for visualization
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).iloc[:36]

# Plot feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance from Random Forest Classifier')
plt.show()

# %%
list_3 = feature_importance_df[feature_importance_df['Importance']>0]['Feature'].to_list()

# %%
list_2 = feature_importance_df['Feature'].to_list()
list_2
# Out:
# ['Curricular units (Average grade)',
#  'Curricular units 2nd sem (grade)',
#  'Debtor',
#  'Grouped Age at enrollment',
#  'Gender',
#  'Curricular units 2nd sem (evaluations)',
#  'Grouped Admission grade',
#  'Marital status',
#  'Course_9556',
#  'Course_9500',
#  'Course_9670',
#  'Course_9238',
#  'Course_9773',
#  'Course_9853',
#  'Course_9991',
#  "Mother's qualification_1",
#  'Course_9254',
#  'Course_9119',
#  'Course_9147',
#  'Course_9130',
#  "Mother's qualification_19",
#  'Course_9085',
#  'Course_9070',
#  'Course_9003',
#  'Course_8014',
#  'Course_33',
#  'Application mode_others',
#  'Application mode_7',
#  'Application mode_51',
#  "Mother's qualification_12",
#  "Mother's qualification_37",
#  "Mother's qualification_2",
#  "Father's qualification_38",
#  'Previous_Age_Interaction',
#  'Grade_Interaction',
#  'Completion_Age_Interaction']

# %%
list_1 = ['AdmGrades_category',
 'Admission grade',
 'Age at enrollment',
 'Application mode_39',
 'Completion_Age_Interaction',
 'Completion_Grade_Interaction',
 'Completion_Rate_1st',
 'Completion_Rate_2nd',
 'Course_8014',
 'Course_9991',
 'Curricular units (Average grade)',
 'Curricular units 1st sem (approved)',
 'Curricular units 1st sem (grade)',
 'Curricular units 2nd sem (approved)',
 'Curricular units 2nd sem (enrolled)',
 'Curricular units 2nd sem (evaluations)',
 'Curricular units 2nd sem (grade)',
 "Father's occupation_0",
 "Father's occupation_90",
 "Father's occupation_others",
 "Father's qualification_3",
 "Father's qualification_34",
 "Father's qualification_37",
 'Grade_Interaction',
 'Grouped Admission grade',
 'Grouped Age at enrollment',
 'Grouped Curricular units 1st sem (grade)',
 'Grouped Curricular units 2nd sem (grade)',
 'Grouped Previous qualification (grade)',
 'International',
 "Mother's qualification_3",
 "Mother's qualification_34",
 'Previous_Age_Interaction',
 'Total Curricular units (approved)',
 'Total Curricular units (enrolled)',
 'Total Curricular units (evaluations)']
for l in list:
    list_1.append(l)

for l2 in list_2:
    list_1.append(l2)

for l3 in list_3:
    list_1.append(l3)
list_1
# Out:
# ['AdmGrades_category',
#  'Admission grade',
#  'Age at enrollment',
#  'Application mode_39',
#  'Completion_Age_Interaction',
#  'Completion_Grade_Interaction',
#  'Completion_Rate_1st',
#  'Completion_Rate_2nd',
#  'Course_8014',
#  'Course_9991',
#  'Curricular units (Average grade)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  "Father's occupation_0",
#  "Father's occupation_90",
#  "Father's occupation_others",
#  "Father's qualification_3",
#  "Father's qualification_34",
#  "Father's qualification_37",
#  'Grade_Interaction',
#  'Grouped Admission grade',
#  'Grouped Age at enrollment',
#  'Grouped Curricular units 1st sem (grade)',
#  'Grouped Curricular units 2nd sem (grade)',
#  'Grouped Previous qualification (grade)',
#  'International',
#  "Mother's qualification_3",
#  "Mother's qualification_34",
#  'Previous_Age_Interaction',
#  'Total Curricular units (approved)',
#  'Total Curricular units (enrolled)',
#  'Total Curricular units (evaluations)',
#  'Course_9130',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  "Father's occupation_9",
#  'Inflation rate',
#  'Completion_Age_Interaction',
#  'Completion_Grade_Interaction',
#  'Completion_Rate_2nd',
#  'Completion_Rate_1st',
#  "Mother's occupation_4",
#  'Course_9119',
#  'Curricular units (Average grade)',
#  'Application mode_51',
#  'Course_9773',
#  'Course_9853',
#  'Course_9991',
#  "Father's qualification_2",
#  'Application mode_17',
#  "Father's qualification_1",
#  'Curricular units 2nd sem (approved)',
#  'Unemployment rate',
#  'Curricular units 2nd sem (enrolled)',
#  'Gender',
#  'Previous qualification (grade)',
#  'Admission grade',
#  'Previous_Age_Interaction',
#  'Curricular units 1st sem (grade)',
#  'Tuition fees up to date',
#  'Debtor',
#  'Curricular units 1st sem (approved)',
#  'Age at enrollment',
#  'International',
#  'Grade_Interaction',
#  'Curricular units 1st sem (evaluations)',
#  'Scholarship holder',
#  'Course_9556',
#  'Curricular units (Average grade)',
#  'Curricular units 2nd sem (grade)',
#  'Debtor',
#  'Grouped Age at enrollment',
#  'Gender',
#  'Curricular units 2nd sem (evaluations)',
#  'Grouped Admission grade',
#  'Marital status',
#  'Course_9556',
#  'Course_9500',
#  'Course_9670',
#  'Course_9238',
#  'Course_9773',
#  'Course_9853',
#  'Course_9991',
#  "Mother's qualification_1",
#  'Course_9254',
#  'Course_9119',
#  'Course_9147',
#  'Course_9130',
#  "Mother's qualification_19",
#  'Course_9085',
#  'Course_9070',
#  'Course_9003',
#  'Course_8014',
#  'Course_33',
#  'Application mode_others',
#  'Application mode_7',
#  'Application mode_51',
#  "Mother's qualification_12",
#  "Mother's qualification_37",
#  "Mother's qualification_2",
#  "Father's qualification_38",
#  'Previous_Age_Interaction',
#  'Grade_Interaction',
#  'Completion_Age_Interaction',
#  'Curricular units (Average grade)',
#  'Curricular units 2nd sem (grade)',
#  'Debtor',
#  'Grouped Age at enrollment',
#  'Gender',
#  'Curricular units 2nd sem (evaluations)',
#  'Grouped Admission grade']

# %%
count = {}
for var in list_1:
    if var in count:
        count[var] += 1
    else:
        count[var] = 1

count
# Out:
# {'AdmGrades_category': 1,
#  'Admission grade': 2,
#  'Age at enrollment': 2,
#  'Application mode_39': 1,
#  'Completion_Age_Interaction': 3,
#  'Completion_Grade_Interaction': 2,
#  'Completion_Rate_1st': 2,
#  'Completion_Rate_2nd': 2,
#  'Course_8014': 2,
#  'Course_9991': 3,
#  'Curricular units (Average grade)': 4,
#  'Curricular units 1st sem (approved)': 2,
#  'Curricular units 1st sem (grade)': 2,
#  'Curricular units 2nd sem (approved)': 2,
#  'Curricular units 2nd sem (enrolled)': 2,
#  'Curricular units 2nd sem (evaluations)': 4,
#  'Curricular units 2nd sem (grade)': 4,
#  "Father's occupation_0": 1,
#  "Father's occupation_90": 1,
#  "Father's occupation_others": 1,
#  "Father's qualification_3": 1,
#  "Father's qualification_34": 1,
#  "Father's qualification_37": 1,
#  'Grade_Interaction': 3,
#  'Grouped Admission grade': 3,
#  'Grouped Age at enrollment': 3,
#  'Grouped Curricular units 1st sem (grade)': 1,
#  'Grouped Curricular units 2nd sem (grade)': 1,
#  'Grouped Previous qualification (grade)': 1,
#  'International': 2,
#  "Mother's qualification_3": 1,
#  "Mother's qualification_34": 1,
#  'Previous_Age_Interaction': 3,
#  'Total Curricular units (approved)': 1,
#  'Total Curricular units (enrolled)': 1,
#  'Total Curricular units (evaluations)': 1,
#  'Course_9130': 2,
#  "Father's occupation_9": 1,
#  'Inflation rate': 1,
#  "Mother's occupation_4": 1,
#  'Course_9119': 2,
#  'Application mode_51': 2,
#  'Course_9773': 2,
#  'Course_9853': 2,
#  "Father's qualification_2": 1,
#  'Application mode_17': 1,
#  "Father's qualification_1": 1,
#  'Unemployment rate': 1,
#  'Gender': 3,
#  'Previous qualification (grade)': 1,
#  'Tuition fees up to date': 1,
#  'Debtor': 3,
#  'Curricular units 1st sem (evaluations)': 1,
#  'Scholarship holder': 1,
#  'Course_9556': 2,
#  'Marital status': 1,
#  'Course_9500': 1,
#  'Course_9670': 1,
#  'Course_9238': 1,
#  "Mother's qualification_1": 1,
#  'Course_9254': 1,
#  'Course_9147': 1,
#  "Mother's qualification_19": 1,
#  'Course_9085': 1,
#  'Course_9070': 1,
#  'Course_9003': 1,
#  'Course_33': 1,
#  'Application mode_others': 1,
#  'Application mode_7': 1,
#  "Mother's qualification_12": 1,
#  "Mother's qualification_37": 1,
#  "Mother's qualification_2": 1,
#  "Father's qualification_38": 1}

# %%
z = []
for i,j in count.items():
    if count[i] >=1:
        z.append(i)
z
# Out:
# ['AdmGrades_category',
#  'Admission grade',
#  'Age at enrollment',
#  'Application mode_39',
#  'Completion_Age_Interaction',
#  'Completion_Grade_Interaction',
#  'Completion_Rate_1st',
#  'Completion_Rate_2nd',
#  'Course_8014',
#  'Course_9991',
#  'Curricular units (Average grade)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (grade)',
#  "Father's occupation_0",
#  "Father's occupation_90",
#  "Father's occupation_others",
#  "Father's qualification_3",
#  "Father's qualification_34",
#  "Father's qualification_37",
#  'Grade_Interaction',
#  'Grouped Admission grade',
#  'Grouped Age at enrollment',
#  'Grouped Curricular units 1st sem (grade)',
#  'Grouped Curricular units 2nd sem (grade)',
#  'Grouped Previous qualification (grade)',
#  'International',
#  "Mother's qualification_3",
#  "Mother's qualification_34",
#  'Previous_Age_Interaction',
#  'Total Curricular units (approved)',
#  'Total Curricular units (enrolled)',
#  'Total Curricular units (evaluations)',
#  'Course_9130',
#  "Father's occupation_9",
#  'Inflation rate',
#  "Mother's occupation_4",
#  'Course_9119',
#  'Application mode_51',
#  'Course_9773',
#  'Course_9853',
#  "Father's qualification_2",
#  'Application mode_17',
#  "Father's qualification_1",
#  'Unemployment rate',
#  'Gender',
#  'Previous qualification (grade)',
#  'Tuition fees up to date',
#  'Debtor',
#  'Curricular units 1st sem (evaluations)',
#  'Scholarship holder',
#  'Course_9556',
#  'Marital status',
#  'Course_9500',
#  'Course_9670',
#  'Course_9238',
#  "Mother's qualification_1",
#  'Course_9254',
#  'Course_9147',
#  "Mother's qualification_19",
#  'Course_9085',
#  'Course_9070',
#  'Course_9003',
#  'Course_33',
#  'Application mode_others',
#  'Application mode_7',
#  "Mother's qualification_12",
#  "Mother's qualification_37",
#  "Mother's qualification_2",
#  "Father's qualification_38"]

# %% [markdown]
# Dimensional Reduction
# 1. PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)
X_pca = pca.fit_transform(X_train)
pca.n_components_
# Out:
# 38

# %%
# Get the loading scores
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

# Create a DataFrame for the loadings
loading_df = pd.DataFrame(loadings, columns=[f'PC{i+1}' for i in range(pca.n_components_)],
                          index=X_train.columns)

# %%
# Analyze the first few principal components
for i in range(loading_df.shape[1]):
    print(f"\nPrincipal Component {i+1}:")
    component_loadings = loading_df.iloc[:, i]
    
    # Sort features by their absolute loadings
    sorted_loadings = component_loadings.abs().sort_values(ascending=False)
    
    # Display top features
    top_features = sorted_loadings[sorted_loadings > 0.2]
    print(top_features)
# Out:
# Principal Component 1:
# Grouped Curricular units 1st sem (grade)    1.355953
# Grouped Curricular units 2nd sem (grade)    1.142733
# Curricular units 1st sem (approved)         0.921281
# Completion_Rate_1st                         0.914470
# Curricular units 1st sem (grade)            0.910823
# Completion_Grade_Interaction                0.908638
# Total Curricular units (approved)           0.907587
# Curricular units (Average grade)            0.906869
# Curricular units 2nd sem (approved)         0.905337
# Curricular units 2nd sem (grade)            0.902510
# Completion_Rate_2nd                         0.884923
# Completion_Age_Interaction                  0.862102
# Grouped Age at enrollment                   0.779168
# Curricular units 2nd sem (evaluations)      0.556133
# Total Curricular units (evaluations)        0.534066
# Grouped Previous qualification (grade)      0.509913
# Curricular units 1st sem (evaluations)      0.478094
# Grouped Admission grade                     0.417109
# Total Curricular units (enrolled)           0.388436
# Curricular units 2nd sem (enrolled)         0.388032
# Curricular units 1st sem (enrolled)         0.369869
# Age at enrollment                           0.365758
# Grade_Interaction                           0.326141
# Previous_Age_Interaction                    0.295436
# Admission grade                             0.291273
# Previous qualification (grade)              0.270746
# Name: PC1, dtype: float64
#
# Principal Component 2:
# Grouped Previous qualification (grade)    1.453113
# Grouped Admission grade                   1.104728
# Grade_Interaction                         0.903650
# Previous qualification (grade)            0.836929
# Admission grade                           0.763325
# Total Curricular units (evaluations)      0.300216
# Curricular units 2nd sem (evaluations)    0.298673
# Curricular units 1st sem (evaluations)    0.293881
# Previous_Age_Interaction                  0.251985
# AdmGrades_category                        0.221725
# Completion_Age_Interaction                0.221226
# Curricular units 1st sem (approved)       0.212385
# Curricular units (Average grade)          0.206800
# Total Curricular units (approved)         0.202457
# Name: PC2, dtype: float64
#
# Principal Component 3:
# Grouped Age at enrollment                 1.544645
# Previous_Age_Interaction                  0.833499
# Age at enrollment                         0.790076
# Application order                         0.635167
# Curricular units 1st sem (evaluations)    0.383224
# Curricular units 1st sem (enrolled)       0.381649
# Total Curricular units (enrolled)         0.350836
# Total Curricular units (evaluations)      0.347369
# Curricular units 2nd sem (evaluations)    0.323135
# Curricular units 2nd sem (enrolled)       0.295739
# Completion_Age_Interaction                0.227345
# Grouped Admission grade                   0.217600
# Application mode_1                        0.204698
# Application mode_39                       0.202374
# Name: PC3, dtype: float64
#
# Principal Component 4:
# Total Curricular units (enrolled)           0.783006
# Curricular units 2nd sem (enrolled)         0.773874
# Curricular units 1st sem (enrolled)         0.749826
# Application order                           0.364788
# Grouped Curricular units 1st sem (grade)    0.291334
# Grouped Age at enrollment                   0.250365
# Grouped Previous qualification (grade)      0.250096
# GDP                                         0.228749
# Grouped Curricular units 2nd sem (grade)    0.220662
# Name: PC4, dtype: float64
#
# Principal Component 5:
# Total Curricular units (evaluations)        0.613285
# Curricular units 1st sem (evaluations)      0.592862
# Curricular units 2nd sem (evaluations)      0.546543
# Grouped Curricular units 1st sem (grade)    0.508747
# Grouped Curricular units 2nd sem (grade)    0.476257
# Curricular units 2nd sem (enrolled)         0.253878
# Total Curricular units (enrolled)           0.230483
# Grouped Age at enrollment                   0.219031
# Name: PC5, dtype: float64
#
# Principal Component 6:
# Application order                         0.968571
# Unemployment rate                         0.444480
# GDP                                       0.253781
# Grouped Age at enrollment                 0.236182
# Grouped Previous qualification (grade)    0.213279
# Previous_Age_Interaction                  0.203974
# Name: PC6, dtype: float64
#
# Principal Component 7:
# Grouped Admission grade                   0.658021
# Grouped Previous qualification (grade)    0.548346
# Admission grade                           0.468083
# GDP                                       0.308128
# Previous qualification (grade)            0.295411
# Unemployment rate                         0.261262
# Inflation rate                            0.206333
# Name: PC7, dtype: float64
#
# Principal Component 8:
# GDP                                         0.630314
# Unemployment rate                           0.603167
# Application order                           0.451713
# Grouped Previous qualification (grade)      0.237126
# Grouped Curricular units 1st sem (grade)    0.208135
# Name: PC8, dtype: float64
#
# Principal Component 9:
# Grouped Curricular units 1st sem (grade)    0.647459
# Completion_Rate_2nd                         0.265191
# Total Curricular units (evaluations)        0.262028
# Curricular units 1st sem (evaluations)      0.250574
# GDP                                         0.237526
# Total Curricular units (approved)           0.236475
# Curricular units 2nd sem (approved)         0.229446
# Curricular units 2nd sem (evaluations)      0.223095
# Inflation rate                              0.201042
# Completion_Rate_1st                         0.200796
# Name: PC9, dtype: float64
#
# Principal Component 10:
# Inflation rate       0.904052
# Unemployment rate    0.307787
# Name: PC10, dtype: float64
#
# Principal Component 11:
# Grouped Curricular units 2nd sem (grade)    0.561444
# Grouped Curricular units 1st sem (grade)    0.258168
# Curricular units 1st sem (grade)            0.235484
# Curricular units 2nd sem (grade)            0.227417
# Completion_Age_Interaction                  0.214375
# Completion_Grade_Interaction                0.209722
# Name: PC11, dtype: float64
#
# Principal Component 12:
# GDP                  0.527428
# Unemployment rate    0.478146
# Inflation rate       0.251355
# Name: PC12, dtype: float64
#
# Principal Component 13:
# Mother's occupation_9        0.306142
# Grouped Age at enrollment    0.235984
# Father's qualification_37    0.231628
# Mother's qualification_37    0.223461
# Name: PC13, dtype: float64
#
# Principal Component 14:
# Grouped Age at enrollment    0.285770
# Age at enrollment            0.281091
# Name: PC14, dtype: float64
#
# Principal Component 15:
# Grouped Curricular units 2nd sem (grade)    0.256448
# Completion_Rate_2nd                         0.218884
# Name: PC15, dtype: float64
#
# Principal Component 16:
# Application mode_1     0.319711
# Application mode_17    0.260061
# Name: PC16, dtype: float64
#
# Principal Component 17:
# Mother's qualification_19    0.249376
# Mother's qualification_1     0.204130
# Father's qualification_19    0.203304
# Name: PC17, dtype: float64
#
# Principal Component 18:
# Gender    0.258647
# Name: PC18, dtype: float64
#
# Principal Component 19:
# Series([], Name: PC19, dtype: float64)
#
# Principal Component 20:
# Series([], Name: PC20, dtype: float64)
#
# Principal Component 21:
# Displaced    0.293955
# Name: PC21, dtype: float64
#
# Principal Component 22:
# Series([], Name: PC22, dtype: float64)
#
# Principal Component 23:
# Displaced    0.246759
# Gender       0.200503
# Name: PC23, dtype: float64
#
# Principal Component 24:
# Series([], Name: PC24, dtype: float64)
#
# Principal Component 25:
# Series([], Name: PC25, dtype: float64)
#
# Principal Component 26:
# Series([], Name: PC26, dtype: float64)
#
# Principal Component 27:
# Series([], Name: PC27, dtype: float64)
#
# Principal Component 28:
# Series([], Name: PC28, dtype: float64)
#
# Principal Component 29:
# Series([], Name: PC29, dtype: float64)
#
# Principal Component 30:
# Series([], Name: PC30, dtype: float64)
#
# Principal Component 31:
# Series([], Name: PC31, dtype: float64)
#
# Principal Component 32:
# Series([], Name: PC32, dtype: float64)
#
# Principal Component 33:
# Series([], Name: PC33, dtype: float64)
#
# Principal Component 34:
# Series([], Name: PC34, dtype: float64)
#
# Principal Component 35:
# Series([], Name: PC35, dtype: float64)
#
# Principal Component 36:
# Series([], Name: PC36, dtype: float64)
#
# Principal Component 37:
# Series([], Name: PC37, dtype: float64)
#
# Principal Component 38:
# Series([], Name: PC38, dtype: float64)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.31379469, 0.13888873, 0.11842677, 0.05763963, 0.04316934,
#        0.03309197, 0.0306561 , 0.02751787, 0.02515664, 0.02245423,
#        0.01670244, 0.01407274, 0.01062575, 0.00813376, 0.00743544,
#        0.00620157, 0.00589061, 0.00498262, 0.00487234, 0.00459304,
#        0.00441541, 0.00436632, 0.00408145, 0.00400674, 0.00382236,
#        0.00362195, 0.00337294, 0.00325771, 0.00318011, 0.00298807,
#        0.00282233, 0.00277076, 0.00275097, 0.00267772, 0.00242898,
#        0.00238226, 0.00219384, 0.00213964])

# %% [markdown]
# T-SNE

# %%
from sklearn.manifold import TSNE
tsne =TSNE(n_components=2,perplexity=20,random_state=42)
tsne_df = tsne.fit_transform(X_train)
fig = plt.figure(figsize=(10,10))
plt.scatter(tsne_df[:,0],tsne_df[:,1],c=y)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
X_train[z].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3452 entries, 1 to 4423
# Data columns (total 73 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   AdmGrades_category                        3452 non-null   int64
#  1   Admission grade                           3452 non-null   float64
#  2   Age at enrollment                         3452 non-null   float64
#  3   Application mode_39                       3452 non-null   float64
#  4   Completion_Age_Interaction                3452 non-null   float64
#  5   Completion_Grade_Interaction              3452 non-null   float64
#  6   Completion_Rate_1st                       3452 non-null   float64
#  7   Completion_Rate_2nd                       3452 non-null   float64
#  8   Course_8014                               3452 non-null   float64
#  9   Course_9991                               3452 non-null   float64
#  10  Curricular units (Average grade)          3452 non-null   float64
#  11  Curricular units 1st sem (approved)       3452 non-null   float64
#  12  Curricular units 1st sem (grade)          3452 non-null   float64
#  13  Curricular units 2nd sem (approved)       3452 non-null   float64
#  14  Curricular units 2nd sem (enrolled)       3452 non-null   float64
#  15  Curricular units 2nd sem (evaluations)    3452 non-null   float64
#  16  Curricular units 2nd sem (grade)          3452 non-null   float64
#  17  Father's occupation_0                     3452 non-null   float64
#  18  Father's occupation_90                    3452 non-null   float64
#  19  Father's occupation_others                3452 non-null   float64
#  20  Father's qualification_3                  3452 non-null   float64
#  21  Father's qualification_34                 3452 non-null   float64
#  22  Father's qualification_37                 3452 non-null   float64
#  23  Grade_Interaction                         3452 non-null   float64
#  24  Grouped Admission grade                   3452 non-null   category
#  25  Grouped Age at enrollment                 3452 non-null   category
#  26  Grouped Curricular units 1st sem (grade)  3452 non-null   category
#  27  Grouped Curricular units 2nd sem (grade)  3452 non-null   category
#  28  Grouped Previous qualification (grade)    3452 non-null   category
#  29  International                             3452 non-null   int64
#  30  Mother's qualification_3                  3452 non-null   float64
#  31  Mother's qualification_34                 3452 non-null   float64
#  32  Previous_Age_Interaction                  3452 non-null   float64
#  33  Total Curricular units (approved)         3452 non-null   float64
#  34  Total Curricular units (enrolled)         3452 non-null   float64
#  35  Total Curricular units (evaluations)      3452 non-null   float64
#  36  Course_9130                               3452 non-null   float64
#  37  Father's occupation_9                     3452 non-null   float64
#  38  Inflation rate                            3452 non-null   float64
#  39  Mother's occupation_4                     3452 non-null   float64
#  40  Course_9119                               3452 non-null   float64
#  41  Application mode_51                       3452 non-null   float64
#  42  Course_9773                               3452 non-null   float64
#  43  Course_9853                               3452 non-null   float64
#  44  Father's qualification_2                  3452 non-null   float64
#  45  Application mode_17                       3452 non-null   float64
#  46  Father's qualification_1                  3452 non-null   float64
#  47  Unemployment rate                         3452 non-null   float64
#  48  Gender                                    3452 non-null   int64
#  49  Previous qualification (grade)            3452 non-null   float64
#  50  Tuition fees up to date                   3452 non-null   int64
#  51  Debtor                                    3452 non-null   int64
#  52  Curricular units 1st sem (evaluations)    3452 non-null   float64
#  53  Scholarship holder                        3452 non-null   int64
#  54  Course_9556                               3452 non-null   float64
#  55  Marital status                            3452 non-null   int64
#  56  Course_9500                               3452 non-null   float64
#  57  Course_9670                               3452 non-null   float64
#  58  Course_9238                               3452 non-null   float64
#  59  Mother's qualification_1                  3452 non-null   float64
#  60  Course_9254                               3452 non-null   float64
#  61  Course_9147                               3452 non-null   float64
#  62  Mother's qualification_19                 3452 non-null   float64
#  63  Course_9085                               3452 non-null   float64
#  64  Course_9070                               3452 non-null   float64
#  65  Course_9003                               3452 non-null   float64
#  66  Course_33                                 3452 non-null   float64
#  67  Application mode_others                   3452 non-null   float64
#  68  Application mode_7                        3452 non-null   float64
#  69  Mother's qualification_12                 3452 non-null   float64
#  70  Mother's qualification_37                 3452 non-null   float64
#  71  Mother's qualification_2                  3452 non-null   float64
#  72  Father's qualification_38                 3452 non-null   float64
# dtypes: category(5), float64(61), int64(7)
# memory usage: 1.8 MB

# %%
data_csv = X_train[z]
new_data = pd.concat([data_csv,y_train,school_df[['Curricular units 1st sem (enrolled)']]], axis=1)
# new_data.drop(['Course_8014','Course_9991','Course_9130','Course_9119','Course_9773','Course_9853'],axis=1,inplace=True)
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3452 entries, 1 to 4423
# Data columns (total 75 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   AdmGrades_category                        3452 non-null   int64
#  1   Admission grade                           3452 non-null   float64
#  2   Age at enrollment                         3452 non-null   float64
#  3   Application mode_39                       3452 non-null   float64
#  4   Completion_Age_Interaction                3452 non-null   float64
#  5   Completion_Grade_Interaction              3452 non-null   float64
#  6   Completion_Rate_1st                       3452 non-null   float64
#  7   Completion_Rate_2nd                       3452 non-null   float64
#  8   Course_8014                               3452 non-null   float64
#  9   Course_9991                               3452 non-null   float64
#  10  Curricular units (Average grade)          3452 non-null   float64
#  11  Curricular units 1st sem (approved)       3452 non-null   float64
#  12  Curricular units 1st sem (grade)          3452 non-null   float64
#  13  Curricular units 2nd sem (approved)       3452 non-null   float64
#  14  Curricular units 2nd sem (enrolled)       3452 non-null   float64
#  15  Curricular units 2nd sem (evaluations)    3452 non-null   float64
#  16  Curricular units 2nd sem (grade)          3452 non-null   float64
#  17  Father's occupation_0                     3452 non-null   float64
#  18  Father's occupation_90                    3452 non-null   float64
#  19  Father's occupation_others                3452 non-null   float64
#  20  Father's qualification_3                  3452 non-null   float64
#  21  Father's qualification_34                 3452 non-null   float64
#  22  Father's qualification_37                 3452 non-null   float64
#  23  Grade_Interaction                         3452 non-null   float64
#  24  Grouped Admission grade                   3452 non-null   category
#  25  Grouped Age at enrollment                 3452 non-null   category
#  26  Grouped Curricular units 1st sem (grade)  3452 non-null   category
#  27  Grouped Curricular units 2nd sem (grade)  3452 non-null   category
#  28  Grouped Previous qualification (grade)    3452 non-null   category
#  29  International                             3452 non-null   int64
#  30  Mother's qualification_3                  3452 non-null   float64
#  31  Mother's qualification_34                 3452 non-null   float64
#  32  Previous_Age_Interaction                  3452 non-null   float64
#  33  Total Curricular units (approved)         3452 non-null   float64
#  34  Total Curricular units (enrolled)         3452 non-null   float64
#  35  Total Curricular units (evaluations)      3452 non-null   float64
#  36  Course_9130                               3452 non-null   float64
#  37  Father's occupation_9                     3452 non-null   float64
#  38  Inflation rate                            3452 non-null   float64
#  39  Mother's occupation_4                     3452 non-null   float64
#  40  Course_9119                               3452 non-null   float64
#  41  Application mode_51                       3452 non-null   float64
#  42  Course_9773                               3452 non-null   float64
#  43  Course_9853                               3452 non-null   float64
#  44  Father's qualification_2                  3452 non-null   float64
#  45  Application mode_17                       3452 non-null   float64
#  46  Father's qualification_1                  3452 non-null   float64
#  47  Unemployment rate                         3452 non-null   float64
#  48  Gender                                    3452 non-null   int64
#  49  Previous qualification (grade)            3452 non-null   float64
#  50  Tuition fees up to date                   3452 non-null   int64
#  51  Debtor                                    3452 non-null   int64
#  52  Curricular units 1st sem (evaluations)    3452 non-null   float64
#  53  Scholarship holder                        3452 non-null   int64
#  54  Course_9556                               3452 non-null   float64
#  55  Marital status                            3452 non-null   int64
#  56  Course_9500                               3452 non-null   float64
#  57  Course_9670                               3452 non-null   float64
#  58  Course_9238                               3452 non-null   float64
#  59  Mother's qualification_1                  3452 non-null   float64
#  60  Course_9254                               3452 non-null   float64
#  61  Course_9147                               3452 non-null   float64
#  62  Mother's qualification_19                 3452 non-null   float64
#  63  Course_9085                               3452 non-null   float64
#  64  Course_9070                               3452 non-null   float64
#  65  Course_9003                               3452 non-null   float64
#  66  Course_33                                 3452 non-null   float64
#  67  Application mode_others                   3452 non-null   float64
#  68  Application mode_7                        3452 non-null   float64
#  69  Mother's qualification_12                 3452 non-null   float64
#  70  Mother's qualification_37                 3452 non-null   float64
#  71  Mother's qualification_2                  3452 non-null   float64
#  72  Father's qualification_38                 3452 non-null   float64
#  73  Target                                    3452 non-null   int64
#  74  Curricular units 1st sem (enrolled)       3452 non-null   float64
# dtypes: category(5), float64(62), int64(8)
# memory usage: 1.9 MB

# %%
new_data.to_csv('new_data.csv')
